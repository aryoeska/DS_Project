# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./smart_city_dataset (1).csv')
df.head()
# Out:
#   City Name  Population  Area (sq. km)  Smart Infrastructure Score  \
# 0     City1     5096012         618.03                       60.36
# 1     City2     6354413         931.44                        3.39
# 2     City3     5757525         160.87                       90.22
# 3     City4     9154133         657.85                       81.41
# 4     City5     3714568         169.38                       48.59
#
#    Energy Consumption  Public Transport Usage  Air Quality Index  \
# 0              337.59                   33.79              52.05
# 1              917.83                   20.30              11.59
# 2              678.09                   79.10              44.62
# 3              369.49                   63.72              62.36
# 4              666.52                   30.59              30.86
#
#    Education Index  Healthcare Index  Employment Rate  Smart Grid Adoption  \
# 0            54.97             88.72            33.70                 8.99
# ...

# %% [markdown]
# Population
# Area (sq. km)
# Smart Infrastructure Score
# Energy Consumption
# Public Transport Usage
# Air Quality Index
# Education Index
# Healthcare Index
# Employment Rate
# Smart Grid Adoption
# Waste Management Score
# Internet Speed (Mbps)
# Safety Index
# Cost of Living Index

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   City Name                   5000 non-null   object
#  1   Population                  5000 non-null   int64
#  2   Area (sq. km)               5000 non-null   float64
#  3   Smart Infrastructure Score  5000 non-null   float64
#  4   Energy Consumption          5000 non-null   float64
#  5   Public Transport Usage      5000 non-null   float64
#  6   Air Quality Index           5000 non-null   float64
#  7   Education Index             5000 non-null   float64
#  8   Healthcare Index            5000 non-null   float64
#  9   Employment Rate             5000 non-null   float64
#  10  Smart Grid Adoption         5000 non-null   float64
#  11  Waste Management Score      5000 non-null   float64
#  12  Internet Speed (Mbps)       5000 non-null   float64
# ...

# %% [markdown]
# Terdapat beberapa kota yang direncanakan sebagai smart city

# %%
df.describe()
# Out:
#          Population  Area (sq. km)  Smart Infrastructure Score  \
# count  5.000000e+03    5000.000000                 5000.000000
# mean   5.055296e+06     501.097182                   50.152668
# std    2.886202e+06     284.963902                   28.751349
# min    1.083200e+04      10.100000                    0.040000
# 25%    2.526708e+06     252.367500                   25.560000
# 50%    5.101918e+06     502.000000                   50.140000
# 75%    7.535613e+06     750.417500                   75.230000
# max    9.997692e+06     999.360000                   99.940000
#
#        Energy Consumption  Public Transport Usage  Air Quality Index  \
# count          5000.00000             5000.000000        5000.000000
# mean            547.34314               42.778352          55.495874
# std             260.11661               21.774003          26.047696
# min             100.12000                5.010000          10.000000
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.scatterplot(data=df, x='Area (sq. km)', y='Smart Infrastructure Score')
# Out:
# <Axes: xlabel='Area (sq. km)', ylabel='Smart Infrastructure Score'>

# %%
sns.histplot(df['Smart Infrastructure Score'], bins=20)
# Out:
# c:\Users\Aryo Sasi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Smart Infrastructure Score', ylabel='Count'>

# %% [markdown]
# kota dengan skor infrastruktur 0 - 100 (semakin tinggi semakin bagus), merata di beberapa kota sehingga dapat dikatakan bahwa masih banyak terdapat kota" yang memiliki pembangunan yang kurang merata

# %%
sns.histplot(df['Cost of Living Index'], bins=20)
# Out:
# c:\Users\Aryo Sasi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Cost of Living Index', ylabel='Count'>

# %% [markdown]
# kota - kota yang ada juga masih terpadat ketimpangan biaya hidup terlihat dari visualisasi yang merata dari yang biaya hidup terkecil hingga terbesar

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.model_selection import train_test_split

# %%
X = df.drop(['Smart Infrastructure Score', 'City Name'], axis=1)
y = df['Smart Infrastructure Score']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
model = LinearRegression()

model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

print(f'MAE Score : {mean_absolute_error(y_test, y_pred)}')
print(f'MSE Score : {mean_squared_error(y_test, y_pred)}')
# Out:
# MAE Score : 24.88164354564585
# MSE Score : 828.1559767260986

# %%
plt.figure(figsize=(12, 8))

# acutal values
plt.plot([i for i in range(len(y_test))],np.array(y_test), c='g', label="actual values")

# predicted values
plt.plot([i for i in range(len(y_test))],y_pred, c='m',label="predicted values")
plt.legend()
plt.show()

# %%
model_params = {
    'lin_reg': {
        'model': LinearRegression(),
        'params' : {
        }  
    },
    'ridge': {
        'model': Ridge(),
        'params' : {
            'alpha': [0.1, 1, 10, 100, 200]
        }
    },
    'lasso' : {
        'model': Lasso(),
        'params': {
             'alpha': [0.1, 1, 10, 100, 200]
        }
    }
}

# %%
from sklearn.model_selection import GridSearchCV

scores = []

for model_name, mp in model_params.items():
    clf = GridSearchCV(mp['model'], mp['params'], cv = 5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model':model_name,
        'best_score':clf.best_score_,
        'best_params':clf.best_params_
    })

# %%
df = pd.DataFrame(scores, columns=['model', 'best_score', 'best_params'])
df
# Out:
#      model  best_score     best_params
# 0  lin_reg   -0.007650              {}
# 1    ridge   -0.007649  {'alpha': 200}
# 2    lasso   -0.003615  {'alpha': 200}

# %%
lin_reg = Lasso(alpha=200)

lin_reg.fit(X_train, y_train)
# Out:
# Lasso(alpha=200)

# %%
y_pred = lin_reg.predict(X_test)

# %%
print(f'MSE {mean_squared_error(y_test, y_pred)}')
print(f'MAE {mean_absolute_error(y_test, y_pred)}')
# Out:
# MSE 825.4827931505938
# MAE 24.849717486276724
